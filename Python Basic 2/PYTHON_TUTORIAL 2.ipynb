# %% [markdown]
# # Plotting Functions using Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xmin = input('Xmin =')
# Out:
# Xmin =10

# %%
xmin = int(xmin)

# %%
xmax = input('Xmax=')
# Out:
# Xmax=100

# %%
xmax = int(xmax)

# %%
xmin = -2*np.pi
xmax = 2*np.pi

x = np.arange(xmin,xmax,0.1) #x from xmin to xmax




y1 = -np.sin(x)*np.cos(x)  #f(x) = sin(x)*cos(x)

y2 = np.sin(x)/x

# %%
# %matplotlib Notebook

plt.figure(figsize=(10,5)) #sets up the figure size

plt.xlabel('x') #xlabel
plt.ylabel('y(x)') #ylabel
plt.title("Plotting Two Functions Together")
plt.plot(x,y1,'1',lw=2,label="Sin(x)Cos(x)")
plt.plot(x,y2,'.',lw=2,label="Sinc(x)")
plt.legend()
plt.grid()

plt.show()
plt.savefig("twofunc.pdf")
# Out:
# Traceback (most recent call last):
#   File "/home/pranav/.local/lib/python3.7/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/home/pranav/.local/lib/python3.7/site-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Plotting Subplots

# %%
xmin = -5; xmax =5; Npoints=500
dx = (xmax-xmin)/Npoints


x1 = np.arange(xmin,xmax,dx) #creating different x arrays
x2 = np.arange(xmin,xmax,dx/20)

y1 = -np.sin(x1)*np.cos(x1*x1)
y2 = np.exp(-x2/4)*np.sin(x2)


y3 = np.exp(-x1**2/4)
y4 = np.sin(x2)

# %%
# %matplotlib Notebook

plt.figure(1,figsize=(10,5))



plt.subplot(2,2,1)   #2 rows, 2 column, plot1
plt.plot(x1,y1,'r',lw=2)
plt.show()


plt.subplot(2,2,2)#2 rows, 2 column,plot2
plt.plot(x2,y2,'-',lw=2)
plt.show()

plt.subplot(2,2,3)#2 rows, 2 column,plot3
plt.plot(x1,y3,'k--',lw=2)
plt.show()

plt.subplot(2,2,4)#2 rows, 2 column,plot4
plt.plot(x2,y4,'+g',lw=1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib Notebook



fig,ax = plt.subplots(2,1,sharex=True)
ax[0].plot(x1,y1*y1,'r',lw=2)
ax[0].set_title("Different Functions on subplots ")
ax[1].set_xlabel("x value")
ax[1].set_ylabel("f2(x) value")
ax[0].set_ylabel("f1(x) value")
ax[1].plot(x2,y2*y2,'-',lw=2)

plt.savefig("subplotexample.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Color-Magnitude Diagram

# %%
u,g = np.loadtxt ('Skyserver_SQL4_23_2020 10_38_19 AM.csv', unpack = True, skiprows=2,usecols = (1,2), delimiter = ',')

# %%
# %matplotlib Notebook

plt.figure(figsize=(7,5))
plt.xlabel("u-g")
plt.ylabel("u")
plt.title("CMD of a Star Cluster")
plt.grid()
plt.plot(u-g,u,"ko",markersize=0.6)

plt.savefig("cmd.pdf")
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
import pandas as pd

dataframe = pd.read_csv('Skyserver_SQL4_23_2020 10_38_19 AM.csv',skiprows=1)

# %%
dataframe.head()
# Out:
#                  objid         u         g         r         i         z
# 0  1237668355109617845  15.64877  14.65252  14.55741  14.22900  13.33909
# 1  1237668355109617848  16.42908  14.98056  14.36546  14.10973  13.94392
# 2  1237668355109617849  16.53623  15.13512  14.51652  14.26310  14.09655
# 3  1237668355109617850  15.89986  14.83650  14.47984  14.37411  14.32596
# 4  1237668355109617851  16.18958  14.97118  14.85165  14.84361  14.81034

# %%
dataframe['u']
# Out:
# 0       15.64877
# 1       16.42908
# 2       16.53623
# 3       15.89986
# 4       16.18958
#           ...
# 1331    25.07740
# 1332    25.67852
# 1333    24.14375
# 1334    25.30115
# 1335    24.19160
# Name: u, Length: 1336, dtype: float64

# %%
dataframe.columns
# Out:
# Index(['objid', 'u', 'g', 'r', 'i', 'z'], dtype='object')

# %%
u = dataframe['u'].to_numpy()
g = dataframe['g'].to_numpy()
i = dataframe['i'].to_numpy()
z = dataframe['z'].to_numpy()

# %%
# %matplotlib Notebook


fig, axes = plt.subplots(nrows=2, ncols=1)
fig.tight_layout(pad=4)

axes[0].plot(u-g,u,'r.',markersize=0.5)
axes[0].set_xlabel("u-g")
axes[0].set_ylabel("u")
axes[0].set_title("CMD for u-g and i-z")

axes[1].plot(i-z,i,'bo',markersize=0.5)
axes[1].set_xlabel("i-z")
axes[1].set_ylabel("z")


plt.savefig("cmdsubplot.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x = np.arange(0,10,1)
y = x**2;

np.savetxt('samplefile.txt',(x,y))    


xi = np.loadtxt('samplefile.txt',unpack=True)

# %%
xi
# Out:
# array([[ 0.,  0.],
#        [ 1.,  1.],
#        [ 2.,  4.],
#        [ 3.,  9.],
#        [ 4., 16.],
#        [ 5., 25.],
#        [ 6., 36.],
#        [ 7., 49.],
#        [ 8., 64.],
#        [ 9., 81.]])

# %%
import matplotlib.animation as anime

# %matplotlib Notebook

fig, ax = plt.subplots()
xdata, ydata = [], []
ln, = plt.plot([], [], 'ro',markersize =0.8)
def init():
    ax.set_xlim(0, 2*np.pi)
    ax.set_ylim(-1, 1)
    return ln,

def update(frame):
    xdata.append(frame)
    ydata.append(np.sin(frame))
    ln.set_data(xdata, ydata)
    return ln,

ani = anime.FuncAnimation(fig, update, frames=np.linspace(0, 2*np.pi, 128),
                    init_func=init, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
