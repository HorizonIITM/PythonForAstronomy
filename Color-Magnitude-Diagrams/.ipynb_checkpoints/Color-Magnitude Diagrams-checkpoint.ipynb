# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Hertzsprung russell diagram

# %% [markdown]
# ![image](https://upload.wikimedia.org/wikipedia/commons/thumb/1/17/Hertzsprung-Russel_StarData.png/1024px-Hertzsprung-Russel_StarData.png)
#
#
# The Hertzsprung–Russell diagram, abbreviated as H–R diagram, HR diagram or HRD, is a scatter plot of stars showing the relationship between the stars' absolute magnitudes or luminosities versus their stellar classifications or effective temperatures. The diagram was created independently in around 1910 by Ejnar Hertzsprung and Henry Norris Russell, and represented a major step towards an understanding of stellar evolution.

# %% [markdown]
# ### The various branches in HR diagram
#
# ![image](https://upload.wikimedia.org/wikipedia/commons/6/6b/HRDiagram.png)

# %% [markdown]
# # Evolution of Star Cluster using HR diagram

# %% [markdown]
# At an early time stamp in the star cluster’s formation, what we will call t=0, most of the high mass stars have reached the Main Sequence, while some of the lower mass stars are still in the T Tauri phase.

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/h5p/content/11093/images/file-5d839e213f4b9.png)

# %% [markdown]
# Ten million years ( $10^7$  years) later, the highest mass O stars have used up all of their hydrogen and begin to evolve off the Main Sequence.

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/h5p/content/11093/images/file-5d839f8245a54.png)

# %% [markdown]
# After 100 million years ( $10^8$ , all of the O stars have gone supernova. The B stars begin to evolve off of the Main Sequence.

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/h5p/content/11093/images/file-5d839fd1b134e.png)

# %% [markdown]
# After 1 billion years ( $10^9$  years), All of the B stars that are massive enough have gone supernova and the rest have evolved into red giants. The A stars begin to evolve off of the Main Sequence.

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/h5p/content/11093/images/file-5d83a0b436c81.png)

# %% [markdown]
# After 5 billion years (5x $10^9$ ), The G stars begin to evolve off of the Main Sequence. The red giant branch is populated with some of the originally more massive stars. Some of the first red giant stars that formed have already become white dwarfs.

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/h5p/content/11093/images/file-5d83a01f6f387.png)

# %% [markdown]
# After 10 billion years ( $10^10$  years), The OBAFG stars are all missing from the Main Sequence, the red giant branch is very well populated, and there are also many white dwarfs. Only K & M stars remain on the Main Sequence.

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/h5p/content/11093/images/file-5d83a0685ea3f.png)

# %% [markdown]
# ![image](https://d2jmvrsizmvf4x.cloudfront.net/ntDruuoRcKCnjWikJl8K_images.jpg)

# %% [markdown]
# https://www.spacetelescope.org/videos/heic1211a/

# %% [markdown]
# # Color-Magnitude Diagram

# %% [markdown]
# Observers can't directly measure the luminosities and absolute temperatures. Instead we qantify this using colour and magnitude. The magnitude is related to the luminosity and the colour is of course related to the temperature.

# %% [markdown]
# ![image](http://voyages.sdss.org/wp-content/uploads/2016/08/label.gif)

# %% [markdown]
# ![image](https://www.e-education.psu.edu/astro801/sites/www.e-education.psu.edu.astro801/files/image/Lesson%207/zams.gif)

# %% [markdown]
# # Distance Modulus
#
#
# When we measure the magnitude of a star, we are measuring its apparent magnitude, m. This is its brightness as
# perceived when measured from Earth. Astronomers also use the absolute magnitude, M, of a star, which is defined
# as the apparent magnitude a star would have if we were observing it from ten parsecs away.
#
# Due to the inverse-square law ($F = L 4\pi r^2 $), we can deter mine the *the distance modulus* as,
#
# $$ m - M = 5 log_{10} (\frac{d}{10pc})$$

# %% [markdown]
# ## Isochrones
#
#
# #### Generating Isochrones: http://stev.oapd.inaf.it/cgi-bin/cmd,
#
# Data for clusters: https://www.galaxyzooforum.org/index.php?topic=278836.0,  https://www.galaxyzooforum.org/index.php?PHPSESSID=gtl8r3b6plt4kndjpqrnj27l36&topic=272726.msg197713#msg197713
#
# http://skyserver.sdss.org/dr16/en/tools/chart/navi.aspx

# %%
loga,logl,logte = np.loadtxt('isoc_z008.dat',usecols=(0,3,4),unpack =True)

# %%
w7 = np.where(loga == 7.0)#10**7 
w7_5 = np.where(loga == 7.5)
w8 = np.where(loga == 8.0)
w8_5 = np.where(loga == 8.5)
w9 = np.where(loga == 9.0)

# %%
plt.figure(figsize=[8,5])
    
plt.plot(logte[w7], logl[w7],label='10 Myr')
plt.plot(logte[w8], logl[w8],label='100 Myr')
plt.plot(logte[w7_5], logl[w7_5],label='31.6 Myr')
plt.plot(logte[w8_5], logl[w8_5],label='316.2Myr')
plt.plot(logte[w9], logl[w9],label='1 Byr')


plt.xlabel('Log(Teff)')
plt.ylabel('Log L')
plt.axis([5.0,3.5,0,6])
plt.title("Isochrones for star cluster with metallicity z =0.008")
plt.legend()
plt.savefig("cmdconstmetallicity.pdf")

# %% [markdown]
# But we need observational data which is the u,v magnitudes

# %%
Mb1,Mv1 =  np.loadtxt('isoc_z008.dat',usecols=(8,9),unpack=True)
Mb2,Mv2 =  np.loadtxt('isoc_z0001.dat',usecols=(8,9),unpack=True)
Mb3,Mv3 =  np.loadtxt('isoc_z0004.dat',usecols=(8,9),unpack=True)
Mb4,Mv4 =  np.loadtxt('isoc_z004.dat',usecols=(8,9),unpack=True)
Mb5,Mv5 =  np.loadtxt('isoc_z019.dat',usecols=(8,9),unpack=True)
Mb6,Mv6 =  np.loadtxt('isoc_z030.dat',usecols=(8,9),unpack=True)

# %%
loga1 =  np.loadtxt('isoc_z008.dat',usecols=(0),unpack=True)
loga2 =  np.loadtxt('isoc_z0001.dat',usecols=(0),unpack=True)
loga3 =  np.loadtxt('isoc_z0004.dat',usecols=(0),unpack=True)
loga4 =  np.loadtxt('isoc_z004.dat',usecols=(0),unpack=True)
loga5 =  np.loadtxt('isoc_z019.dat',usecols=(0),unpack=True)
loga6 =  np.loadtxt('isoc_z030.dat',usecols=(0),unpack=True)

# %%
w71 = np.where(loga1 == 8.0)
w72 = np.where(loga2 == 8.0)
w73 = np.where(loga3 == 8.0)
w74 = np.where(loga4 == 8.0)
w75 = np.where(loga5 == 8.0)
w76 = np.where(loga6 == 8.0)

# %%
plt.figure(figsize=[8,5])

plt.scatter(Mb1[w71]-Mv1[w71],Mv1[w71],label='z=0.008',s=1.8)
plt.scatter(Mb2[w72]-Mv2[w72],Mv2[w72],label='z=0.0001',s=1.8)
plt.scatter(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004',s=1.8)
plt.scatter(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04',s=1.8)
plt.scatter(Mb5[w75]-Mv5[w75],Mv5[w75],label='z=0.019',s=1.8)
plt.scatter(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030',s=1.8)
plt.title("Isochrones for star cluster with age 100 Myr")
plt.xlabel('B-V')
plt.ylabel('V')
plt.legend()
plt.savefig("cmdconstage.pdf")

# %% [markdown]
# ## M45:  Pleiades star cluster
#
#
# ![image](https://apod.nasa.gov/apod/image/1909/m45_lorenzi_960.jpg)

# %%
w71 = np.where(loga1 == 10.0)
w72 = np.where(loga2 == 10.0)
w73 = np.where(loga3 == 10.0)
w74 = np.where(loga4 == 10.0)
w75 = np.where(loga5 == 10.0)
w76 = np.where(loga6 == 10.0)

# %%
M45v,M45bv = np.loadtxt("m45.dat",usecols=(2,3),unpack=True)

# %%
plt.figure(figsize=[8,5])

plt.scatter(Mb1[w71]-Mv1[w71],Mv1[w71],label='z=0.008',s=1.8)
plt.scatter(Mb2[w72]-Mv2[w72],Mv2[w72],label='z=0.0001',s=1.8)
plt.scatter(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004',s=1.8)
plt.scatter(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04',s=1.8)
plt.scatter(Mb5[w75]-Mv5[w75],Mv5[w75],label='z=0.019',s=1.8)
plt.scatter(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030',s=1.8)
plt.scatter(M45bv,M45v,s=1.2)
plt.title("Isochrones for star cluster with age 100 Myr")

plt.legend()

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004')
plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030')
plt.scatter(M45bv,M45v,s=1.2)
plt.title("Isochrones for star cluster with age 100 Myr")
plt.legend()

# %%
w71 = np.where(loga1 == 8.2)
w72 = np.where(loga2 == 8.2)
w73 = np.where(loga3 == 8.2)
w74 = np.where(loga4 == 8.2)
w75 = np.where(loga5 == 8.2)
w76 = np.where(loga6 == 8.2)

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004')
plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030')
plt.scatter(M45bv,M45v,s=1.2)
plt.title("Isochrones for star cluster with age 100 Myr")
plt.legend()

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb3[w73]-Mv3[w73],Mv3[w73],label='z=0.004')
plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],label='z=0.030')
plt.scatter(M45bv,M45v-5.2,s=1.2,label="pleiades data")
plt.title("Isochrones for star cluster with age 100 Myr")
plt.legend()

# %%
plt.figure(figsize=[8,5])

plt.plot(Mb4[w74]-Mv4[w74],Mv4[w74],'k--',label='z=0.04')
plt.plot(Mb6[w76]-Mv6[w76],Mv6[w76],'r--',label='z=0.03')
plt.scatter(M45bv,M45v-5.6,s=1.2,label="pleiades data")
plt.title("Isochrone Fitting for M45")
plt.xlabel('B-V')
plt.ylabel('V')
plt.legend()
plt.savefig("Isochronefitting.pdf")

# %% [markdown]
# ### Observations
#
# 1. Metallicity should be around 0.03<=[Fe/H]<=0.04
# 2. Distance Modulus = 5.6
# 3. log10[age] = 8.2
